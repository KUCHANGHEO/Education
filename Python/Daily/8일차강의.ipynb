# %% [markdown]
# ### 연습문제
# - 아이리스 sepal_length 속성에서, 평균을 기준으로 표준편차값 만큼 벗어나는 샘플의 갯수를 구하시오.
# - 다른 세가지 속성에 대해서도 적용해 보시오.
# - sepal_width 값이 petal_length 값 보다 큰 샘플들의 갯수를 구하시오.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris = np.loadtxt('iris.csv', skiprows=1,
                 delimiter=',', usecols=range(4))
iris.shape
# Out:
# (150, 4)

# %%
sl = iris[:, 0]
sl
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.6, 5. , 4.4, 4.9, 5.4, 4.8, 4.8,
#        4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5. ,
#        5. , 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5. , 5.5, 4.9, 4.4,
#        5.1, 5. , 4.5, 4.4, 5. , 5.1, 4.8, 5.1, 4.6, 5.3, 5. , 7. , 6.4,
#        6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5. , 5.9, 6. , 6.1, 5.6,
#        6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6, 6.8, 6.7,
#        6. , 5.7, 5.5, 5.5, 5.8, 6. , 5.4, 6. , 6.7, 6.3, 5.6, 5.5, 5.5,
#        6.1, 5.8, 5. , 5.6, 5.7, 5.7, 6.2, 5.1, 5.7, 6.3, 5.8, 7.1, 6.3,
#        6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5,
#        7.7, 7.7, 6. , 6.9, 5.6, 7.7, 6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2,
#        7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6. , 6.9, 6.7, 6.9, 5.8,
#        6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9])

# %%
m = sl.mean()
s = sl.std()
m, s
# Out:
# (5.843333333333334, 0.8253012917851409)

# %%
(sl>(m+s)).sum() + (sl<(m-s)).sum()
# Out:
# 60

# %%
(np.abs(sl-m)>s).sum()
# Out:
# 60

# %%
(iris[:,1]>iris[:,2]).sum()
# Out:
# 50

# %%
a = np.random.rand(10000)
a
# Out:
# array([0.80805236, 0.97281858, 0.41909538, ..., 0.73954302, 0.45862051,
#        0.68878472])

# %%
plt.hist(a)
# Out:
# (array([1007., 1005., 1021.,  970., 1010., 1000.,  980., 1024.,  985.,
#          998.]),
#  array([4.13689841e-05, 1.00025274e-01, 2.00009178e-01, 2.99993083e-01,
#         3.99976987e-01, 4.99960892e-01, 5.99944796e-01, 6.99928701e-01,
#         7.99912605e-01, 8.99896510e-01, 9.99880414e-01]),
#  <BarContainer object of 10 artists>)

# %%
a = np.random.randn(1000000)

# %% [markdown]
# - -1~1 사이의 샘플 갯수를 구하시오
# - -2~2 사이
# - -3~3 사이
# - 위에서 구한 값을 확률로 전환해 보시오.

# %%
a = np.random.randn(1000000)

# %%
(np.abs(a)<1).sum() /1000000
# Out:
# 0.682394

# %%
(np.abs(a)<2).sum() / 1000000
# Out:
# 0.954498

# %%
(np.abs(a)<3).sum() /1000000
# Out:
# 0.997269

# %%
plt.hist(a, bins=100)
pass

# %%
np.random.randint(3, size=10)
# Out:
# array([1, 0, 0, 1, 1, 2, 2, 1, 0, 0])

# %%
np.random.randint(1, 3, size=10)
# Out:
# array([2, 2, 2, 1, 1, 1, 1, 2, 1, 2])

# %%
np.random.randint(1, 7, size=[10,3])
# Out:
# array([[3, 6, 3],
#        [5, 5, 4],
#        [6, 2, 6],
#        [6, 4, 4],
#        [4, 1, 3],
#        [2, 6, 1],
#        [2, 5, 4],
#        [2, 2, 6],
#        [6, 5, 1],
#        [6, 5, 5]])

# %%
a = np.random.randn(100,10)
a
# Out:
# array([[-6.37349793e-01, -6.52113037e-01,  3.61599470e-01,
#          1.10966099e+00,  1.55593165e+00, -1.41531492e+00,
#         -8.30193522e-01,  5.33513576e-01,  4.13293370e-01,
#          9.26606118e-01],
#        [-7.44103147e-01,  5.96240638e-01, -1.52663167e-01,
#         -4.12671665e-01,  3.86336431e-01,  8.44995815e-01,
#         -2.15933594e-01,  7.49119912e-01, -1.13078280e+00,
#          1.35061732e+00],
#        [-6.24437848e-01,  1.22979675e-02, -1.10216013e+00,
#         -1.26471360e+00,  3.74189310e-01,  2.57461660e-02,
#         -2.56665719e-01,  5.44450687e-01, -4.80292264e-01,
#          8.25409755e-01],
#        [-1.10192861e+00,  8.58487789e-01,  5.02574579e-01,
#          1.69716104e+00,  1.14823655e+00, -1.71772977e-01,
#          4.57094309e-01,  2.97382305e-01,  9.69927577e-02,
#          4.14668177e-03],
#        [-1.61580200e-01,  3.62354373e-02, -1.53198559e+00,
#          1.42220839e+00,  3.92343550e-01, -1.50887783e+00,
# ...

# %%
(a>3).sum(), (a<-3).sum()
# Out:
# (2, 2)

# %%
a[a>3] = 3

# %%
a[a<-3] = -3

# %%
a[np.abs(a)>3]
# Out:
# array([], dtype=float64)

# %%
data = np.zeros([100,2])

# %%
np.random.randn(100)
# Out:
# array([ 1.24071591e+00,  8.73235601e-01,  1.26464987e+00, -2.36652280e+00,
#         1.84746817e-03, -7.82760414e-01, -7.52048123e-01, -8.29152808e-01,
#         7.39614931e-01, -5.45830614e-01,  1.99560068e-01, -1.26287494e+00,
#         1.48780140e+00, -6.32590719e-01,  2.21548389e+00,  1.71197947e+00,
#        -2.67134971e-01, -4.65518568e-01,  6.12562337e-01, -2.47015889e+00,
#         5.32198907e-01,  1.60856382e+00, -3.21002052e-01, -2.86428967e-02,
#        -9.65253326e-03,  1.53574649e+00, -1.10687677e+00, -4.71770175e-01,
#         3.43282059e-01, -1.05104379e+00, -9.80732676e-01, -2.37890699e-01,
#         3.00128288e-01, -6.17154594e-01,  2.00537244e-01, -2.90288067e-01,
#        -7.32053192e-01,  2.91304594e-01, -1.03598675e+00, -5.95943572e-01,
#         8.69679113e-01,  9.89758639e-02, -8.00215394e-01,  3.35149234e-01,
#        -8.15435083e-01,  1.74089761e+00,  5.35891524e-01,  1.16776933e-01,
# ...

# %%
data[:, 0] = np.random.randn(100)

# %%
data[:, 1] = np.random.normal(10, 5, size=100)

# %%
plt.scatter(data[:,0], data[:,1], alpha=0.2) # 산점도
plt.axis('equal') # 축들의 스케일을 균등하게
# Out:
# (-2.8045244070357347,
#  2.448335665732057,
#  -2.430291417115699,
#  23.302474573193265)

# %%
plt.scatter(iris[:,0], iris[:,1], alpha=0.2)

# %%
img = np.random.randn(100,100) # 각각의 값은 밝기 (brightness)
img
# Out:
# array([[ 0.61492891,  1.24965169, -0.28570141, ..., -0.62481448,
#          0.54192749, -0.2106376 ],
#        [ 0.31780135,  0.72759031,  0.77670267, ..., -1.05800709,
#         -0.65297388, -0.54449458],
#        [ 0.33039264, -1.47882095,  0.66483292, ..., -0.11494117,
#          1.14516538,  0.77885517],
#        ...,
#        [-1.58710987,  0.17758025, -0.28171356, ..., -0.95758272,
#         -1.93055101,  0.18836446],
#        [ 0.81741237, -0.49578967,  0.1032679 , ..., -1.70908697,
#          0.24190798,  1.81269948],
#        [ 0.09531305,  0.81123544, -0.91722385, ...,  1.08312999,
#         -0.07055458, -1.59260458]])

# %%
plt.imshow(img, cmap='gray')
plt.colorbar()

# %%
img = np.zeros([100,100,3])
plt.imshow(img)

# %%
img = np.ones([100,100,3])
plt.imshow(img)

# %%
img = np.ones([100,100,3])/2
plt.imshow(img)

# %%
img = np.zeros([100,100,3])
img[:, :, 0] = 1
plt.imshow(img)

# %%
img = np.zeros([100,100,3])
img[:, :, 1] = 1
plt.imshow(img)

# %%
img = np.zeros([100,100,3])
img[:, :, 2] = 1
plt.imshow(img)

# %%
img = np.zeros([100,100,3])
img[:, :, 0] = 1
img[:, :, 1] = 1
plt.imshow(img)

# %%
bob = plt.imread('bobdylan.jpg')
bob.shape
# Out:
# (1620, 2880, 3)

# %%
plt.imshow(bob)

# %%
bob.min(), bob.max(), bob.dtype
# Out:
# (0, 255, dtype('uint8'))

# %%
bob[:, :, 0].shape
# Out:
# (1620, 2880)

# %%
plt.imshow(bob)

# %%
plt.figure(figsize=[12,6])

plt.subplot(1,3,1)
plt.imshow(bob[:, :, 0], cmap='gray', vmin=0, vmax=255)
plt.axis('off')
plt.title('RED')

plt.subplot(1,3,2)
plt.imshow(bob[:, :, 1], cmap='gray', vmin=0, vmax=255)
plt.axis('off')
plt.title('GREEN')

plt.subplot(1,3,3)
plt.imshow(bob[:, :, 2], cmap='gray', vmin=0, vmax=255)
plt.axis('off')
plt.title('BLUE')
# Out:
# Text(0.5, 1.0, 'BLUE')

# %%
plt.imshow(bob[100:900, 1000:2000])

# %%
plt.imshow(bob[:, :, 1], cmap='gray', vmin=0, vmax=255)

# %%
plt.imshow(bob[:, :, 2], cmap='gray', vmin=0, vmax=255)
