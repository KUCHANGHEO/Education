# %% [markdown]
# ## OpenCV
# # OpenCV 이미지 특성

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
bob = cv2.imread('bob.jpg')

# %% [markdown]
# ### 이미지는 숫자
# - 각 픽셀은 0~255 의 정수임 (np.uint8 타입)

# %%
bob.min(), bob.max()
# Out:
# (0, 255)

# %%
bob[:5,:5,0]
# Out:
# array([[40, 54, 54, 46, 41],
#        [34, 50, 53, 50, 48],
#        [37, 49, 50, 48, 48],
#        [49, 53, 46, 41, 43],
#        [55, 55, 46, 43, 45]], dtype=uint8)

# %%
bob.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# ### 채널은 BGR 순서
# - RGB 가 아닌 Blue-Green-Red 순서임
# - cv2.imshow() 함수도 BGR 형태의 이미지를 입력받음

# %%
bob2 = bob.copy()
bob2[:,:,2] = 0 # 특정 색상 제거

# %%
cv2.imshow('image', bob2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# - RGB 이미지로 전환

# %%
bob2 = bob[:,:,[2,1,0]]
plt.imshow(bob2)

# %% [markdown]
# ### 채널 분리

# %%
blue = bob[:,:,0]
green = bob[:,:,1]
red = bob[:,:,2]

# %%
plt.figure(figsize=[10,4])

plt.subplot(1,3,1)
plt.title('blue')
plt.imshow(blue, cmap='Blues')

plt.subplot(1,3,2)
plt.title('green')
plt.imshow(green, cmap='Greens')

plt.subplot(1,3,3)
plt.title('red')
plt.imshow(red, cmap='Reds')

# %% [markdown]
# ### 이미지 자르기

# %%
bob2 = bob[:200, 100:300]
cv2.imshow('image', bob2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# - 잘라서 붙여넣기

# %%
bob2 = bob.copy()
bob2[100:300, 100:300] = bob[:200,:200]
cv2.imshow('image', bob2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# - 지우기

# %%
bob2 = bob.copy()
bob2[50:150, 100:300] = 0
cv2.imshow('image', bob2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### 밝기 반전

# %%
cv2.imshow('image', 255-bob)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### 대칭 변환

# %%
cv2.imshow('image', bob[::-1])
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow('image', bob[:, ::-1])
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### 회전 변환

# %%
bob2 = np.swapaxes(bob, 0, 1) # np.moveaxis(bob,0,1)
cv2.imshow('image', bob2[::-1])
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
bob2 = np.swapaxes(bob, 0, 1)
cv2.imshow('image', bob2[:,::-1])
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow('image', bob[::-1,::-1])
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### 픽셀값 증가

# %%
cv2.imshoqw('image', bob+128)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-b7768d17b469> in <module>
# ----> 1 cv2.imshoqw('image', bob+128)
#       2 cv2.waitKey(0)
#       3 cv2.destroyAllWindows()
#
# AttributeError: module 'cv2.cv2' has no attribute 'imshoqw'

# %% [markdown]
# - 이미지는 np.uint8 형태이므로 255에 1을 더하면 0이 된다

# %%
bob2 = np.array(bob, dtype=np.uint16)
bob3 = np.minimum(bob2+128,255)
cv2.imshow('image', bob3.astype(np.uint8))
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### 히스토그램

# %%
plt.hist(bob.ravel(), bins=np.arange(257))
pass

# %%
plt.figure(figsize=[5,7])

plt.subplot(3,1,1)
plt.title('blue')
plt.hist(bob[:,:,0].ravel(), bins=np.arange(257))

plt.subplot(3,1,2)
plt.title('green')
plt.hist(bob[:,:,1].ravel(), bins=np.arange(257))

plt.subplot(3,1,3)
plt.title('red')
plt.hist(bob[:,:,2].ravel(), bins=np.arange(257))

pass
